# %% [markdown]
# <a href="https://colab.research.google.com/github/aayele/FDSfE_AAyele/blob/main/distributionParametersDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # demonstration of distributions changing as the parameters change

# %%
#forward compatibility between python2 and python3
from __future__ import print_function,division
#plotting imports
import pylab as pl
import matplotlib
from matplotlib import animation
from IPython.display import HTML
# %pylab inline
pl.style.use("https://raw.githubusercontent.com/fedhere/FDSfE/master/fbb.mplstyle")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#stats imports
import scipy as sp
from scipy import stats

# %%
pl.rcParams['figure.figsize'] = [5.0,4.0]
pl.rcParams['font.size'] = 15

# %% [markdown]
# ## Binomial distribution:
#
# $k=\textstyle {n \choose k}\, p^k (1-p)^{n-k}$
#
# parameters:
#     - n: number of tries
#     - p: probability of success at each try
# defines the probability of having N "successes" in a series of n independent identical success/failure experiment. The case of n=1 and p=0.5 is describe a fair coin toss.
#
# mean: np
#
# variance: np*(1-p)

# %%
Ndistribs = 20 #number of distributions
ssize = 1000 #sample size

#binomial distribution parameters n,p
bin_n = 20 # n parameter
ps = np.linspace(0, 1.0, bin_n) # p parameter

t = np.linspace(0, bin_n, bin_n+1).astype(int) # x axis
y = np.zeros((Ndistribs, ssize)) #container for the distributions
ls = np.zeros((Ndistribs, len(t))) #container for gaussians corresponding to the distribs

#loop to generate a distribution for each p value
for i,j in enumerate(ps):
    # binomial
    y[i] = sp.stats.binom.rvs(n=bin_n, p=j, size=ssize)
    # gaussian with same mean
    ls[i] = sp.stats.binom.pmf(t, n=bin_n, p=j)

#prepare figure
fig, ax = pl.subplots();
ax.axis([-20, 35, 0, 0.4]);

# get and plot histogram of initial distributions
y0 = np.histogram(y[0], bins=t, density=1)[0]
n, bins, patches = plt.hist(y0, bins=t, density=1,
                            facecolor='SteelBlue', alpha=0.75);
#plot Gaussians
l,= ax.plot(t, ls[i]);

#add label
texts = ax.text(0.65, 0.8,  'p = %.2f\nn = %d'%(ps[0], bin_n),
                transform=ax.transAxes,
               fontsize=15)

#line at 0
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
#axis labels
ax.set_title("Binomial: change p")
ax.set_ylabel("probability of N successes")
ax.set_xlabel("N")

#animation function
def animate(i):
    ''' matplotlib animation call
    i: loop iterator
    returns the patches
    '''
    n, _ = np.histogram(y[i], bins=t, density=1)
    for rect, h in zip(patches, n):
        #regenerate histogram
        rect.set_height(h)
    #regenerate gaussian line
    l.set_data(t, ls[i])
    #regenerate label
    texts.set_text('p = %.2f\nn = %d'%(ps[i], bin_n))
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y));

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imga7069cdf00f8411bbaf537b8ee5a628c">
#   <div class="anim-controls">
#     <input id="_anim_slidera7069cdf00f8411bbaf537b8ee5a628c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anima7069cdf00f8411bbaf537b8ee5a628c.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anima7069cdf00f8411bbaf537b8ee5a628c.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecta7069cdf00f8411bbaf537b8ee5a628c" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_a7069cdf00f8411bbaf537b8ee5a628c"
#              >
#       <label for="_anim_radio1_a7069cdf00f8411bbaf537b8ee5a628c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_a7069cdf00f8411bbaf537b8ee5a628c"
#              checked>
#       <label for="_anim_radio2_a7069cdf00f8411bbaf537b8ee5a628c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_a7069cdf00f8411bbaf537b8ee5a628c"
#              >
#       <label for="_anim_radio3_a7069cdf00f8411bbaf537b8ee5a628c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imga7069cdf00f8411bbaf537b8ee5a628c";
#     var slider_id = "_anim_slidera7069cdf00f8411bbaf537b8ee5a628c";
#     var loop_select_id = "_anim_loop_selecta7069cdf00f8411bbaf537b8ee5a628c";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3deVyU1f7A8c8MIwIi4BqKS6Khpbii\
# uCCoiXUzrMgFV7gqqLlrpZaVqQl6XVJRSfPKldyXfldLyTW9amVm5G4SLriQJJsoizHP7w9ichr2\
# GRmGvu/Xy9fLOc95Hr7PDB7PnOec71EpiqIghBCi3FGbOwAhhBD5kwZaCCHKKWmghRCinJIGWggh\
# yilpoIUQopySBloIIcopaaCFEKKckgZaCCHKKWmghRCinJIGWgghyilpoIUQopySBloIIcopaaCF\
# EKKckgZaCCHKKWmgLVzTpk2ZPn26ucMoEWNjHjp0KD169DBhRAWzxPdXVBwacwcg/vTdd98xbNgw\
# vTJra2tq165Nhw4dGDlyJI0bNzZTdEKIsiYNdDn08ssv4+3tDUBWVhaXL19m27ZtfPXVV+zevRsX\
# Fxdd3TNnzqBWW9YXIUuMWQhzkA

# %% [markdown]
# ## Poisson distribution:
# $k=\frac{\lambda^k}{k!} e^{-\lambda}$
#
# parameters:
#     - lambda: number of tries
# A discrete distribution that expresses the probability of a number of events
# occurring in a fixed period of time if these events occur with a known average rate
# and independently of the time since the last event. More here http://individual.utoronto.ca/zheli/poisson.pdf
#
# mean: lambda
#
# variance: lambda

# %%
Ndistribs = 20 #number of distributions

#Poisson distribution parameters lambda
n = 20 # n parameter
lambdas = np.linspace(0, Ndistribs-1, Ndistribs).astype(int)# lambda parameter

t = np.linspace(-0.5, n*2, n*4+2) # x axis
t2 = np.linspace(0, n*2, n*2+1) # x axis
y = np.zeros((Ndistribs, ssize)) #container for the distributions
ls = np.zeros((Ndistribs, int(len(t) / 2))) #container for gaussians corresponding to the distribs


#loop to generate a distribution for each p value
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.poisson.rvs(size=ssize, mu=j)
    ls[i] = sp.stats.poisson.pmf(t2, mu=j)
    #pl.figure()
    #pl.hist(y[i])

#prepare figure
fig, ax = pl.subplots();
ax.axis([-n, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t2, ls[i])
texts = ax.text(0.50, 0.9,  'lambda = %d'%lambdas[0], transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Poisson: change lambda")
ax.set_ylabel("probability of N")
ax.set_xlabel("N")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    l.set_data(t2, ls[i])
    texts.set_text('lambda = %d'%lambdas[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0999180075a748efb0fa96e5c8a0a63b">
#   <div class="anim-controls">
#     <input id="_anim_slider0999180075a748efb0fa96e5c8a0a63b" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0999180075a748efb0fa96e5c8a0a63b.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim0999180075a748efb0fa96e5c8a0a63b.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select0999180075a748efb0fa96e5c8a0a63b" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0999180075a748efb0fa96e5c8a0a63b"
#              >
#       <label for="_anim_radio1_0999180075a748efb0fa96e5c8a0a63b">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0999180075a748efb0fa96e5c8a0a63b"
#              checked>
#       <label for="_anim_radio2_0999180075a748efb0fa96e5c8a0a63b">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0999180075a748efb0fa96e5c8a0a63b"
#              >
#       <label for="_anim_radio3_0999180075a748efb0fa96e5c8a0a63b">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0999180075a748efb0fa96e5c8a0a63b";
#     var slider_id = "_anim_slider0999180075a748efb0fa96e5c8a0a63b";
#     var loop_select_id = "_anim_loop_select0999180075a748efb0fa96e5c8a0a63b";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3de3hM1+I+8HcSQogRlLoEFTGpyyRC\
# CBLRIIJUEUIokiIHv0hdj1ud00rrklbrkrhUKEVJKjhtNXJEKCdF8o1WaU+aNqIixC0iF3LP/v2h\
# M8c2SYzs2Wai7+d5+rSzZu09a8+k76xZa6+9FYIgCCAiIpNjZuwGEBFR5RjQREQmigFNRGSiGNBE\
# RCaKAU1EZKIY0EREJooBTURkohjQREQmigFNRGSiGNBERCaKAU1EZKIY0EREJooBTURkohjQREQm\
# igFtIuzt7bFkyRJjN8MkZGZmwt7eHmFhYcZuynM3cOBATJ482ahtSExMhL29PQ4dOmQS+/krq2Ps\
# BtQ2iYmJmDJliqisQYMG6NChA0aOHIlJkybB3NzcSK0johcJA7qGXn/9dbi7u0MQBNy+fRuHDx/G\
# qlWrkJaWhvfff/+Z93fx4kWYmf

# %% [markdown]
# ## Gaussian
#
# $x= \frac{1}{\sigma\sqrt{2\pi}}\, e^{-\frac{(x - \mu)^2}{2 \sigma^2}}$
#
# parameters:
#     - mu: mean
#     - sigma: standard deviation
# It relates to the Central Limit Theorem:
# (Under some conditions which include finite variance) the averages of samples
# of random variables independently drawn from _any_ distributions
# converge in distribution to the normal, i.e.,
# they become normally distributed with mean equal to the expected value and
# sdtandard deviation equal to the square root of the mean.
#
# Also referred to Normal if mean is 0 and Standard Normal if mean is 0 and standard deviation is 1
#
# mean: mu
#
# variance: sigma^2

# %%
Ndistribs = 21
nminmax = 35
t = np.linspace(-nminmax, nminmax, nminmax+1).astype(int)
y = np.zeros((Ndistribs, ssize))
ls = np.zeros((Ndistribs, len(t)))
sigs = np.linspace(1, Ndistribs, Ndistribs).astype(int) # parameter variance
mu = 3 # parameter mean

for i,j in enumerate(sigs):
    #print(mus[i])
    y[i] = sp.stats.norm.rvs(size=ssize, loc=mu, scale=j)
    ls[i] = sp.stats.norm.pdf(t, loc=mu, scale=j)
    #pl.figure()
    #pl.hist(y[i])

fig, ax = pl.subplots()
ax.axis([-20, 20, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.7, 0.8,  'sig = %d\nmu=%d'%(sigs[0], mu), transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian: chanhe variance")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    l.set_data(t, ls[i])
    texts.set_text('sig = %d\nmu = %d'%(sigs[i], mu))
    return patches
print(r"changing variance")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
# Out:
# changing variance

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img13b5bbed719047b0a620a94a630964f8">
#   <div class="anim-controls">
#     <input id="_anim_slider13b5bbed719047b0a620a94a630964f8" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim13b5bbed719047b0a620a94a630964f8.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim13b5bbed719047b0a620a94a630964f8.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select13b5bbed719047b0a620a94a630964f8" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_13b5bbed719047b0a620a94a630964f8"
#              >
#       <label for="_anim_radio1_13b5bbed719047b0a620a94a630964f8">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_13b5bbed719047b0a620a94a630964f8"
#              checked>
#       <label for="_anim_radio2_13b5bbed719047b0a620a94a630964f8">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_13b5bbed719047b0a620a94a630964f8"
#              >
#       <label for="_anim_radio3_13b5bbed719047b0a620a94a630964f8">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img13b5bbed719047b0a620a94a630964f8";
#     var slider_id = "_anim_slider13b5bbed719047b0a620a94a630964f8";
#     var loop_select_id = "_anim_loop_select13b5bbed719047b0a620a94a630964f8";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3dd1iT1/s/8HcSwhICbpkqImgFREWw\
# Am60Sq2W4mirQrUoXu7xdbXW0Vqw1VqRopWqXNWqfD5of9ZWsW6kKFTr/NSFsQIKLjYyQvL8/oCk\
# xATITkju13V5tTk5z/OcDG4O93MGi2EYBoQQQgwOW98NIIQQIh8FaEIIMVAUoAkhxEBRgCaEEANF\
# AZoQQgwUBWhCCDFQFKAJIcRAUYAmhBADRQGaEEIMFAVoQggxUBSgCSHEQFGAJoQQA0UBmhBCDBQF\
# aEIIMVAUoI1UXl4ePD09sW3bNn03RS3Dhg3D1KlT9d0MeHp6YsWKFfpuhlYdPnwYnp6eyMzM1HdT\
# SD0zfTfAEFRXVyMlJQUnTpzAvXv3UFZWBisrK3Tu3BkDBgxAWFgYunXrpu9mEkJMjMkH6NzcXMya\
# NQsPHjyAv78/IiMj0b59e7x69Q

# %%
sig = 4
mus = np.linspace(0, 20, 21).astype(int)
for i,j in enumerate(mus):
    #print(mus[i])
    y[i] = sp.stats.norm.rvs(size=ssize, loc=j, scale=sig)
    ls[i] = sp.stats.norm.pdf(t, loc=j, scale=sig)
    #pl.figure()
    #pl.hist(y[i])
fig, ax = pl.subplots()
ax.axis([-20, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.70, 0.8,  'mu = %d\nsig = %d'%(mus[0], sig), transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian: change mean")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('mu = %d\nsig= %d'%(mus[i], sig))
    l.set_data(t, ls[i])
    return patches

print(r"changing mean")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
# Out:
# changing mean

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img1ecf0dfb9cb645b4aa046c012f6280f0">
#   <div class="anim-controls">
#     <input id="_anim_slider1ecf0dfb9cb645b4aa046c012f6280f0" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim1ecf0dfb9cb645b4aa046c012f6280f0.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim1ecf0dfb9cb645b4aa046c012f6280f0.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select1ecf0dfb9cb645b4aa046c012f6280f0" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_1ecf0dfb9cb645b4aa046c012f6280f0"
#              >
#       <label for="_anim_radio1_1ecf0dfb9cb645b4aa046c012f6280f0">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_1ecf0dfb9cb645b4aa046c012f6280f0"
#              checked>
#       <label for="_anim_radio2_1ecf0dfb9cb645b4aa046c012f6280f0">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_1ecf0dfb9cb645b4aa046c012f6280f0"
#              >
#       <label for="_anim_radio3_1ecf0dfb9cb645b4aa046c012f6280f0">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img1ecf0dfb9cb645b4aa046c012f6280f0";
#     var slider_id = "_anim_slider1ecf0dfb9cb645b4aa046c012f6280f0";
#     var loop_select_id = "_anim_loop_select1ecf0dfb9cb645b4aa046c012f6280f0";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3deVgT17sH8G8SCHsArSuICgougCAI\
# LohiRatoVS4WbV2olmofl7rVrYuVtqKt1aqIVn+2XrUqLWpbW7Tu8qMuFCuKVlGIIrgrSwgkZJm5\
# f3hJiQkYNicJ7+d5eNqcOTPzTgZfTk7mnMNjWZYFIYQQo8PnOgBCCCH6UYImhBAjRQmaEEKMFCVo\
# QggxUpSgCSHESFGCJoQQI0UJmhBCjBQlaEIIMVKUoAkhxEhRgiaEECNFCZoQQowUJWhCCDFSlKAJ\
# IcRIUYImhBAjRQmaaCkoKICXlxc2bNjAdSj1MmjQIEycOJHrMAipFwuuAzBlFRUVSE5Oxh9//IEb\
# N26gtLQUNjY2aN++PXr37o3IyEh4eHhwHSYhxETxaML+usnPz8e0adOQm5uLoKAg9OvXDy1atEB5\
# eTmuXbuGEydOoKSkBKdOnUKrVq

# %% [markdown]
# ## Chi Squared
#
# $x=\frac{1}{2^{\frac{k}{2}}\Gamma\left(\frac{k}{2}\right)}\\; x^{\frac{k}{2}-1} e^{-\frac{x}{2}}$
#
# parameters:
#     - k: degrees of freedom
# the distribution of a sum of the squares of k independent standard normal random variables. The most common distribution in Null Hypothesis Rejection Testing
#
# mean: k
#
# variance: 2k

# %%
lambdas = np.linspace(1, 20, 20).astype(int)
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.chi2.rvs(size=ssize, df=j)
    ls[i] = sp.stats.norm.pdf(t, loc=j, scale=np.sqrt(2 * lambdas[i]))
    #pl.figure()
    #pl.hist(y[i])
fig, ax = pl.subplots()
ax.axis([-20, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
ax.set_title("Chi2: change deg of freedom")

texts = ax.text(0.60, 0.9,  'k = %d'%lambdas[0], transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('k = %d'%lambdas[i])
    l.set_data(t, ls[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(lambdas))

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img0e3723499e704e45b94323bac31db927">
#   <div class="anim-controls">
#     <input id="_anim_slider0e3723499e704e45b94323bac31db927" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim0e3723499e704e45b94323bac31db927.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim0e3723499e704e45b94323bac31db927.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim0e3723499e704e45b94323bac31db927.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select0e3723499e704e45b94323bac31db927" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_0e3723499e704e45b94323bac31db927"
#              >
#       <label for="_anim_radio1_0e3723499e704e45b94323bac31db927">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_0e3723499e704e45b94323bac31db927"
#              checked>
#       <label for="_anim_radio2_0e3723499e704e45b94323bac31db927">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_0e3723499e704e45b94323bac31db927"
#              >
#       <label for="_anim_radio3_0e3723499e704e45b94323bac31db927">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img0e3723499e704e45b94323bac31db927";
#     var slider_id = "_anim_slider0e3723499e704e45b94323bac31db927";
#     var loop_select_id = "_anim_loop_select0e3723499e704e45b94323bac31db927";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3deVxUdb8H8M+ZgWERBkFTXHJBA01B\
# TRQTktwXHtMwBC2FTM0uoqZd126plYp1zWXcHiu97pTac1uQxCW9pMJjRWqZheAOaoAMAwMDM7/7\
# B5wTwwzMmWFgBvi+X69ezzO/OcvvzBm//OZ7fgvHGGMghBBidyS2rgAhhBDjKEATQoidogBNCCF2\
# igI0IYTYKQrQhBBipyhAE0KInaIATQghdooCNCGE2CkK0IQQYqcoQBNCiJ2iAE0IIXaKAjQhhNgp\
# CtCEEGKnKEATQoidogBdxbBhwzBt2jRR2x47dgx+fn5ITU2t51qZ5+7du/Dz88OWLVtsXRW7sWXL\
# Fvj5+eHu3bu2ropod+7cwX/8x39g0KBB8PPzw9KlS626vS2kpqbCz88Px44ds3VVGg0HW1egvqnV\
# aiQkJODEiRPIyMhAUVERPDw80K

# %% [markdown]
# ## Uniform

# %%
t = np.linspace(-Ndistribs, Ndistribs, Ndistribs+1).astype(int)
lambdas = np.linspace(1, Ndistribs, Ndistribs).astype(int)
center = 0
for i,j in enumerate(lambdas):
    #print(mus[i])
    y[i] = sp.stats.uniform.rvs(size=ssize, loc=center, scale=j)
fig, ax = pl.subplots()
ax.axis([-20, 35, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = pl.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
texts = ax.text(0.60, 0.9,  'scale = %d'%lambdas[0], transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Uniform")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    texts.set_text('scale = %d'%lambdas[i])
    l.set_data(t, ls[i])
    return patches

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))

# %%
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img5c7b498101344e36ad318a34bdff4d92">
#   <div class="anim-controls">
#     <input id="_anim_slider5c7b498101344e36ad318a34bdff4d92" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim5c7b498101344e36ad318a34bdff4d92.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim5c7b498101344e36ad318a34bdff4d92.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select5c7b498101344e36ad318a34bdff4d92" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_5c7b498101344e36ad318a34bdff4d92"
#              >
#       <label for="_anim_radio1_5c7b498101344e36ad318a34bdff4d92">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_5c7b498101344e36ad318a34bdff4d92"
#              checked>
#       <label for="_anim_radio2_5c7b498101344e36ad318a34bdff4d92">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_5c7b498101344e36ad318a34bdff4d92"
#              >
#       <label for="_anim_radio3_5c7b498101344e36ad318a34bdff4d92">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5c7b498101344e36ad318a34bdff4d92";
#     var slider_id = "_anim_slider5c7b498101344e36ad318a34bdff4d92";
#     var loop_select_id = "_anim_loop_select5c7b498101344e36ad318a34bdff4d92";
#     var frames = new Array(21);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAgAElEQVR4nO3de1SU1eI+8AdUZAwGxcwbXhhMRAVB\
# ULwQpIIeJcpIBLsIR+VEId7wpJllooZaaeKImJ6jKxWlPOY5JbK8JgdRWFR0bB3ziOMNvyomyIAN\
# oDPv7w8X83McwFcusgefz1qt1bvfvd/ZmxcfNvu9YCVJkgQiIhKOdXN3gIiIasaAJiISFAOaiEhQ\
# DGgiIkExoImIBMWAJiISFAOaiEhQDGgiIkExoImIBMWAJiISFAOaiEhQDGgiIkExoImIBMWAJiIS\
# FAOaLNLChQvh6upqVn7q1ClMnjwZXl5ecHV1xd69e5uhd0SNgwFNTWLv3r11BmRhYSFcXV2xcOHC\
# RvvM0tJSxMXFQafTYeHChVi9ejWGDBnSaMcnetJaN3cHiOpj2bJlWLp0qUnZ6dOnodVqsWLFCowd\
# O7aZekbUeBjQZJHatGljVvb777

# %% [markdown]
# # Changing distribution size

# %%
ssize = np.logspace(0.2,5,20).astype(int)

Ndistribs = len(ssize)
nminmax = 35
t = np.linspace(-nminmax, nminmax, nminmax+1).astype(int)
y = []
ls = np.zeros((Ndistribs, len(t)))
sigs = np.linspace(1, Ndistribs, Ndistribs).astype(int) # parameter variance
mu = 0 # parameter mean

for i,j in enumerate(ssize):
    #print(mus[i])
    y.append(sp.stats.norm.rvs(size=ssize[i], loc=mu, scale=sig))
    ls[i] = sp.stats.norm.pdf(t, loc=mu, scale=sig)
    #pl.figure()
    #pl.hist(y[i])

fig, ax = pl.subplots()
ax.axis([-20, 20, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.01, 0.8,  'size = %d'%ssize[0], transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    l.set_data(t, ls[i])
    texts.set_text('size = %d'%ssize[i])
    return patches
print(r"changing size")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y));
# Out:
# changing size

# %%
HTML(ani.to_jshtml());

# %%
ssize = np.logspace(0.2,5,40).astype(int)

Ndistribs = len(ssize)
nminmax = 35
t = np.linspace(-nminmax, nminmax, nminmax+1).astype(int)
y = []
z = []
ls = np.zeros((Ndistribs, len(t)))
sigs = np.linspace(1, Ndistribs, Ndistribs).astype(int) # parameter variance
mu = 0 # parameter mean

for i,j in enumerate(ssize):
    #print(mus[i])
    y.append(sp.stats.norm.rvs(size=ssize[i], loc=mu, scale=sig))
    z.append(sp.stats.norm.rvs(size=ssize[i], loc=mu, scale=sig))
    ls[i] = sp.stats.norm.pdf(t, loc=mu, scale=sig)
    #pl.figure()
    #pl.hist(y[i])

fig, ax = pl.subplots()
ax.axis([-20, 20, 0, 0.2])
bins = t

y0 = np.histogram(y[0], bins=bins, density=1)[0]
z0 = np.histogram(z[0], bins=bins, density=1)[0]

n, bins, patches = plt.hist(y0, bins, density=1,
                            facecolor='SteelBlue', alpha=0.75);
n2, bins2, patches2 = plt.hist(0, bins, density=1,
                            facecolor='IndianRed', alpha=0.75);
l,= ax.plot(t, ls[i])
texts = ax.text(0.1, 0.9,  'size = %d'%ssize[0], transform=ax.transAxes,
               fontsize=15)
ax.plot([0, 0], [0, 0.4], 'k-', alpha=0.5)
ax.set_title("Gaussian")
ax.set_ylabel("probability of x")
ax.set_xlabel("x")

def animate(i):
    n, _ = np.histogram(y[i], bins=bins, density=1)
    for rect, h in zip(patches, n):
        rect.set_height(h)
    n2, _ = np.histogram(z[i], bins=bins, density=1)
    for rect, h in zip(patches2, n2):
        rect.set_height(h)
    l.set_data(t, ls[i])
    texts.set_text('size = %d'%ssize[i])
    return patches
print(r"are they the same?")
ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(y))
# Out:
# are they the same?

# %%
HTML(ani.to_jshtml());

# %%
HTML(ani.to_html5_video())
# Out:
# <video width="360" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
